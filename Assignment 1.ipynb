# %%
# Assignment 1


#This is my first attempt playing around with the code to create a magic bracelet

x = 1
y = 5
culm = [x,y]
z = x+y
z2 = z+y -10

culm.append(z)
culm.append(z2)

for i in range(200):
    w = z
    z = z2
    z2 = z2 + w
    if z2>= 10:
        z2 -= 10
    
    culm.append(z2)
    
print(culm)
# Out:
# [1, 5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6, 5, 1, 6, 7, 3, 0, 3, 3, 6, 9, 5, 4, 9, 3, 2, 5, 7, 2, 9, 1, 0, 1, 1, 2, 3, 5, 8, 3, 1, 4, 5, 9, 4, 3, 7, 0, 7, 7, 4, 1, 5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6, 5, 1, 6, 7, 3, 0, 3, 3, 6, 9, 5, 4, 9, 3, 2, 5, 7, 2, 9, 1, 0, 1, 1, 2, 3, 5, 8, 3, 1, 4, 5, 9, 4, 3, 7, 0, 7, 7, 4, 1, 5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6, 5, 1, 6, 7, 3, 0, 3, 3, 6, 9, 5, 4, 9, 3, 2, 5, 7, 2, 9, 1, 0, 1, 1, 2, 3, 5, 8, 3, 1, 4, 5, 9, 4, 3, 7, 0, 7, 7, 4, 1, 5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6, 5, 1, 6]

# %%
def bracelet(x,y, N): #This function creates the bracelet following the rules discussed in my Latex code

    culm = [x,y]
    
    z = x+y
    
    if z>=10:
        z-=10
    
    z2 = z+y
    
    if z2>=10:
        z2-=10

    culm.append(z)
    culm.append(z2)
    

    for i in range(N):
        w=z
        z=z2
        z2 = z2 + w
        if z2>= 10:
            z2 -= 10
    
        culm.append(z2)
    
    print(culm)
    print('\n')
    print(len(culm))
    print('\n')


#Testing phase    
    
bracelet(1,5,56)

bracelet(5,6,56)

bracelet(5,1,56)

#Number of unique bracelets

bracelet(1,5,56)

bracelet(6,2,16)

bracelet(0,5,0)

bracelet(1,3,8)

bracelet(8,4,0)

bracelet(0,0,0)

60+20+3+12+1+4  #Checking lengths add to 100
# Out:
# [1, 5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6, 5, 1, 6, 7, 3, 0, 3, 3, 6, 9, 5, 4, 9, 3, 2, 5, 7, 2, 9, 1, 0, 1, 1, 2, 3, 5, 8, 3, 1, 4, 5, 9, 4, 3, 7, 0, 7, 7, 4]
#
#
# 60
#
#
# [5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6, 5, 1, 6, 7, 3, 0, 3, 3, 6, 9, 5, 4, 9, 3, 2, 5, 7, 2, 9, 1, 0, 1, 1, 2, 3, 5, 8, 3, 1, 4, 5, 9, 4, 3, 7, 0, 7, 7, 4, 1]
#
#
# 60
#
#
# [5, 1, 6, 7, 3, 0, 3, 3, 6, 9, 5, 4, 9, 3, 2, 5, 7, 2, 9, 1, 0, 1, 1, 2, 3, 5, 8, 3, 1, 4, 5, 9, 4, 3, 7, 0, 7, 7, 4, 1, 5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6]
#
#
# 60
#
#
# [1, 5, 6, 1, 7, 8, 5, 3, 8, 1, 9, 0, 9, 9, 8, 7, 5, 2, 7, 9, 6, 5, 1, 6, 7, 3, 0, 3, 3, 6, 9, 5, 4, 9, 3, 2, 5, 7, 2, 9, 1, 0, 1, 1, 2, 3, 5, 8, 3, 1, 4, 5, 9, 4, 3, 7, 0, 7, 7, 4]
#
#
# 60
#
#
# [6, 2, 8, 0, 8, 8, 6, 4, 0, 4, 4, 8, 2, 0, 2, 2, 4, 6, 0, 6]
#
#
# 20
#
#
# [0, 5, 5, 0]
#
#
# 4
#
#
# [1, 3, 4, 7, 1, 8, 9, 7, 6, 3, 9, 2]
#
#
# 12
#
#
# [8, 4, 2, 6]
#
#
# 4
#
#
# [0, 0, 0, 0]
#
#
# 4
# 100
